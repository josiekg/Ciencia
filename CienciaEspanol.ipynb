# %%
import random

words = [
    {"Spanish": "átomo", "English": "atom"},
    {"Spanish": "molécula", "English": "molecule"},
    {"Spanish": "energía", "English": "energy"},
    {"Spanish": "fuerza", "English": "force"},
    {"Spanish": "gravedad", "English": "gravity"},
    {"Spanish": "trabajo", "English": "work"},
    {"Spanish": "potencia", "English": "power"},
    {"Spanish": "presión", "English": "pressure"},
    {"Spanish": "temperatura", "English": "temperature"},
    {"Spanish": "densidad", "English": "density"},
    {"Spanish": "masa", "English": "mass"},
    {"Spanish": "volumen", "English": "volume"},
    {"Spanish": "reacción", "English": "reaction"},
    {"Spanish": "hipótesis", "English": "hypothesis"},
    {"Spanish": "teoría", "English": "theory"},
    {"Spanish": "ley", "English": "law"},
    {"Spanish": "experimento", "English": "experiment"},
    {"Spanish": "observación", "English": "observation"},
    {"Spanish": "microscopio", "English": "microscope"},
    {"Spanish": "célula", "English": "cell"},
    {"Spanish": "organismo", "English": "organism"},
    {"Spanish": "genética", "English": "genetics"},
    {"Spanish": "ADN", "English": "DNA"},
    {"Spanish": "mutación", "English": "mutation"},
    {"Spanish": "evolución", "English": "evolution"},
    {"Spanish": "biólogo", "English": "biologist"},
    {"Spanish": "químico", "English": "chemist"},
    {"Spanish": "físico", "English": "physicist"},
    {"Spanish": "astrónomo", "English": "astronomer"},
    {"Spanish": "físico nuclear", "English": "nuclear physicist"},
    {"Spanish": "partícula", "English": "particle"},
    {"Spanish": "neutrón", "English": "neutron"},
    {"Spanish": "protón", "English": "proton"},
    {"Spanish": "electrón", "English": "electron"},
    {"Spanish": "quarks", "English": "quarks"},
    {"Spanish": "luz", "English": "light"},
    {"Spanish": "onda", "English": "wave"},
    {"Spanish": "frecuencia", "English": "frequency"},
    {"Spanish": "longitud de onda", "English": "wavelength"},
    {"Spanish": "vibración", "English": "vibration"},
    {"Spanish": "sonido", "English": "sound"},
    {"Spanish": "campo eléctrico", "English": "electric field"},
    {"Spanish": "campo magnético", "English": "magnetic field"},
    {"Spanish": "circuito", "English": "circuit"},
    {"Spanish": "voltaje", "English": "voltage"},
    {"Spanish": "corriente eléctrica", "English": "electric current"},
    {"Spanish": "resistencia", "English": "resistance"},
    {"Spanish": "conductividad", "English": "conductivity"},
    {"Spanish": "electronegatividad", "English": "electronegativity"},
    {"Spanish": "isótopo", "English": "isotope"},
    {"Spanish": "tabla periódica", "English": "periodic table"},
    {"Spanish": "reacción química", "English": "chemical reaction"},
    {"Spanish": "ácido", "English": "acid"},
    {"Spanish": "base", "English": "base"},
    {"Spanish": "sal", "English": "salt"},
    {"Spanish": "pH", "English": "pH"},
    {"Spanish": "mol", "English": "mole"},
    {"Spanish": "concentración", "English": "concentration"},
    {"Spanish": "disolución", "English": "solution"},
    {"Spanish": "alquimia", "English": "alchemy"},
    {"Spanish": "fusión", "English": "fusion"},
    {"Spanish": "fisión", "English": "fission"},
    {"Spanish": "radioactividad", "English": "radioactivity"},
    {"Spanish": "partícula subatómica", "English": "subatomic particle"},
    {"Spanish": "sistema solar", "English": "solar system"},
    {"Spanish": "planeta", "English": "planet"},
    {"Spanish": "estrella", "English": "star"},
    {"Spanish": "galaxia", "English": "galaxy"},
    {"Spanish": "universo", "English": "universe"},
    {"Spanish": "agujero negro", "English": "black hole"},
    {"Spanish": "astronomía", "English": "astronomy"},
    {"Spanish": "cosmología", "English": "cosmology"},
    {"Spanish": "meteorito", "English": "meteorite"},
    {"Spanish": "cometa", "English": "comet"},
    {"Spanish": "asteroide", "English": "asteroid"},
    {"Spanish": "luna", "English": "moon"},
    {"Spanish": "órbita", "English": "orbit"},
    {"Spanish": "vía láctea", "English": "milky way"},
    {"Spanish": "vacío", "English": "vacuum"},
    {"Spanish": "termodinámica", "English": "thermodynamics"},
    {"Spanish": "conductores", "English": "conductors"},
    {"Spanish": "aislantes", "English": "insulators"},
    {"Spanish": "bioma", "English": "biome"},
    {"Spanish": "ecosistema", "English": "ecosystem"},
    {"Spanish": "ecología", "English": "ecology"},
    {"Spanish": "biodiversidad", "English": "biodiversity"},
    {"Spanish": "sostenibilidad", "English": "sustainability"},
    {"Spanish": "clima", "English": "climate"},
    {"Spanish": "meteorología", "English": "meteorology"},
    {"Spanish": "agua", "English": "water"},
    {"Spanish": "aire", "English": "air"},
    {"Spanish": "suelo", "English": "soil"},
    {"Spanish": "oxígeno", "English": "oxygen"},
    {"Spanish": "carbono", "English": "carbon"},
    {"Spanish": "nitrógeno", "English": "nitrogen"},
    {"Spanish": "hidrógeno", "English": "hydrogen"},
    {"Spanish": "ciclo del carbono", "English": "carbon cycle"},
    {"Spanish": "ciclo del agua", "English": "water cycle"},
    {"Spanish": "contaminación", "English": "pollution"},
    {"Spanish": "reciclaje", "English": "recycling"},
    {"Spanish": "energía renovable", "English": "renewable energy"},
    {"Spanish": "biocombustibles", "English": "biofuels"},
    {"Spanish": "energía solar", "English": "solar energy"},
    {"Spanish": "energía eólica", "English": "wind energy"},
    {"Spanish": "energía geotérmica", "English": "geothermal energy"},
    {"Spanish": "energía hidráulica", "English": "hydroelectric energy"}
    {"Spanish": "prueba unitaria", "English": "unit test"}
]

def quiz_user(words):
    random.shuffle(words)
    score = 0 

    for word in words:
        print(f"What is the Spanish translation of '{word['English']}'?")
        user_answer = input("Your answer: ").strip().lower()
        correct_answer = word['Spanish'].lower()

        if user_answer == correct_answer:
            print("¡Correcto!\n!")
            score += 1
        else:
            print(f"¡Equivocado! la respuesta correcta es '{word['Spanish']}'.\n")
            
    print(f"¡Juego completado! Tu puntuación: {score}/{len(words)}")
    

def main():
    print("¡Bienvenido a la aplicación para el aprendizaje de vocabulario de ciencia en español!")
    input("Presiona 'enter' para empezar a aprender...")
    quiz_user(words)

if __name__ == "__main__":
    main()
# Out:
# ¡Bienvenido a la aplicación para el aprendizaje de vocabulario de ciencia en español!
