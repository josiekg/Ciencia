# %%
import random

words = {
    "materials science and engineering": [
        ("materials", "materiales"), ("properties", "propiedades"), ("structure", "estructura"), ("strength", "resistencia"),
        ("ductility", "ductilidad"), ("flexibility", "flexibilidad"), ("tension", "tensión"), ("compression", "compresión"),
        ("load", "carga"), ("fracture", "fractura"), ("surface", "superficie"), ("stress", "esfuerzo"), ("fatigue", "fatiga"),
        ("corrosion", "corrosión"), ("conductivity", "conductividad"), ("insulator", "aislante"), ("alloy", "aleación"),
        ("steel", "acero"), ("plastic", "plástico"), ("glass", "vidrio"), ("ceramic", "cerámica"), ("nanomaterials", "nanomateriales"),
        ("composite", "composite"), ("microstructure", "microestructura"), ("diffusion", "difusión"), ("crystallization", "cristalización"),
        ("polymer", "polímero"), ("biodegradable material", "material biodegradable"), ("superalloy", "superaleación"), ("conductive material", "material conductivo"),
        ("adhesion", "adhesión"), ("temperature", "temperatura"), ("thermal expansion", "expansión térmica"), ("molding", "moldeo"), ("welding", "soldadura"),
        ("coating", "revestimiento"), ("precipitation", "precipitación"), ("thermal stress", "estrés térmico"), ("fluctuation", "fluctuación"),
        ("composition", "composición"), ("melting point", "punto de fusión"), ("solubility", "solubilidad"), ("tensile strength", "resistencia a la tracción"),
        ("safety", "seguridad"), ("vibration", "vibración"), ("optical property", "propiedad óptica")
    ],
    "geoscience": [
        ("geology", "geología"), ("earthquake", "terremoto"), ("rock", "roca"), ("mineral", "mineral"), ("tectonic plate", "placa tectónica"),
        ("volcanic eruption", "erupción volcánica"), ("magma", "magma"), ("lava", "lava"), ("fault", "falla"), ("metamorphic", "metamórfico"),
        ("sedimentary", "sedimentario"), ("igneous", "ígneo"), ("seism", "sismo"), ("quake", "terremoto"), ("eruption", "erupción"),
        ("groundwater", "agua subterránea"), ("black hole", "agujero negro"), ("coal", "carbón"), ("oil", "petróleo"), ("natural gas", "gas natural"),
        ("stratification", "estratificación"), ("erosion", "erosión"), ("mining", "minería"), ("exploration", "exploración"), ("glaciers", "glaciares"),
        ("terrain", "terreno"), ("earth's crust", "corteza terrestre"), ("core", "núcleo"), ("mantle", "mantos"), ("plate tectonics", "tectónica de placas"),
        ("wind", "viento"), ("surface water", "aguas superficiales"), ("genesis", "génesis"), ("soil erosion", "erosión del suelo"), ("pressure", "presión"),
        ("temperature", "temperatura"), ("salinity", "salinidad"), ("geological map", "mapa geológico"), ("raft", "balsa"), ("sediment", "sedimento"),
        ("seismic intensity", "intensidad sísmica"), ("tectonics", "tectónica"), ("stratification", "estratificación"), ("wildfire", "incendio forestal"),
        ("paleontology", "paleontología"), ("intraplate tectonics", "tectónica intraplaca")
    ],
    "computer science": [
        ("computer", "computadora"), ("algorithm", "algoritmo"), ("programming", "programación"), ("code", "código"), ("programming language", "lenguaje de programación"),
        ("database", "base de datos"), ("operating system", "sistema operativo"), ("network", "red"), ("security", "seguridad"), ("encryption", "encriptación"),
        ("compiler", "compilador"), ("debugging", "depuración"), ("artificial intelligence", "inteligencia artificial"), ("machine learning", "machine learning"),
        ("neural network", "red neuronal"), ("search algorithm", "algoritmo de búsqueda"), ("data structure", "estructura de datos"), ("cloud computing", "computación en la nube"),
        ("internet", "internet"), ("program", "programa"), ("function", "función"), ("variable", "variable"), ("loops", "bucles"), ("conditional", "condicional"),
        ("processor", "procesador"), ("microcontroller", "microcontrolador"), ("concurrency", "concurrencia"), ("assembly language", "lenguaje ensamblador"),
        ("web page", "página web"), ("server", "servidor"), ("client", "cliente"), ("stack", "pila"), ("queue", "cola"), ("quantum computer", "computadora cuántica"),
        ("data", "datos"), ("storage", "almacenamiento"), ("interface", "interfaz"), ("user", "usuario"), ("sorting algorithm", "algoritmo de ordenación"),
        ("software testing", "prueba de software"), ("information system", "sistema de información"), ("cipher", "cifrado"), ("hardware", "hardware"), ("software", "software"),
        ("object-oriented programming", "programación orientada a objetos"), ("data compression", "compresión de datos"), ("coding", "codificación"), ("software development", "desarrollo de software"),
        ("social networks", "redes sociales"), ("web development", "desarrollo web")
    ],
    "physics": [
        ("physics", "física"), ("energy", "energía"), ("law of gravity", "ley de la gravedad"), ("force", "fuerza"), ("mass", "masa"),
        ("velocity", "velocidad"), ("acceleration", "aceleración"), ("work", "trabajo"), ("power", "potencia"), ("pressure", "presión"),
        ("temperature", "temperatura"), ("matter", "materia"), ("motion", "movimiento"), ("momentum", "impulso"), ("electric charge", "carga eléctrica"),
        ("electric field", "campo eléctrico"), ("magnetism", "magnetismo"), ("light", "luz"), ("waves", "ondas"), ("frequency", "frecuencia"),
        ("wavelength", "longitud de onda"), ("resistance", "resistencia"), ("voltage", "voltaje"), ("current", "corriente"), ("Ohm's law", "ley de Ohm"),
        ("electromagnetism", "electromagnetismo"), ("quantum theory", "teoría cuántica"), ("relativity", "relatividad"), ("gravitation", "gravitación"),
        ("string theory", "teoría de cuerdas"), ("boson", "bosón"), ("particle", "partícula"), ("fusion", "fusión"), ("radioactivity", "radiactividad"),
        ("physicist", "físico"), ("experiment", "experimento"), ("atom", "átomo"), ("electron", "electrón"), ("proton", "protón"), ("neutron", "neutrón"),
        ("quark", "quark"), ("field theory", "teoría de campos"), ("superconductivity", "superconductividad"), ("general relativity", "relatividad general"),
        ("particle physics", "física de partículas"), ("special relativity", "teoría de la relatividad especial"), ("Bose-Einstein condensate", "condensado de Bose-Einstein"),
        ("Higgs boson", "bosón de Higgs"), ("kinetic energy", "energía cinética"), ("potential energy", "energía potencial")
    ],
    "biology": [
        ("biology", "biología"), ("cell", "célula"), ("DNA", "ADN"), ("gene", "gen"), ("protein", "proteína"), ("enzyme", "enzima"),
        ("mitochondrion", "mitocondria"), ("nucleus", "núcleo"), ("cell membrane", "membrana celular"), ("ribosome", "ribosoma"), ("chromosome", "cromosoma"),
        ("chloroplast", "cloroplasto"), ("cell theory", "teoría celular"), ("ecosystem", "ecosistema"), ("species", "especie"), ("evolution", "evolución"),
        ("adaptation", "adaptación"), ("photosynthesis", "fotosíntesis"), ("cellular respiration", "respiración celular"), ("biome", "bioma"), ("taxonomy", "taxonomía"),
        ("microbiology", "microbiología"), ("anatomy", "anatomía"), ("physiology", "fisiología"), ("genetics", "genética"), ("biotechnology", "biotecnología"),
        ("medicine", "medicina"), ("virus", "virus"), ("bacteria", "bacteria"), ("fungi", "hongos"), ("plant", "planta"), ("animal", "animal"),
        ("genome", "genoma"), ("theory of evolution", "teoría de la evolución"), ("Mendelism", "mendelismo"), ("biological systems", "sistemas biológicos"),
        ("adaptation to environment", "adaptación al ambiente"), ("cell cycle", "ciclo celular"), ("scientific method", "método científico"), ("thermodynamics", "termodinámica"),
        ("biosphere", "biosfera"), ("microbiome", "microbioma"), ("ecology", "ecología"), ("stem cells", "células madre"), ("embryonic development", "desarrollo embrionario"),
        ("molecular biology", "biología molecular"), ("homeostasis", "homeostasis"), ("evolutionary biology", "biología evolutiva"), ("animal physiology", "fisiología animal")
    ]
}

import random

def quiz_user(subject_words):
    random.shuffle(subject_words)
    score = 0

    for word_pair in subject_words:
        print(f"¿Cuál es la traducción de '{word_pair[0]}'?")
        user_answer = input("Tu respuesta: ").strip().lower()
        correct_answer = word_pair[1].lower()

        if user_answer == correct_answer:
            print("¡Correcto!\n")
            score += 1
        else:
            print(f"¡Incorrecto! La respuesta correcta es '{correct_answer}'.\n")
    
    print(f"¡Fin del juego! Tu puntuación: {score}/{len(subject_words)}")

def main():
    print("¡Bienvenido a la aplicación para el aprendizaje de vocabulario de ciencia en español!")
    input("Presiona 'enter' para empezar a aprender...")

    print("Elige un tema de estudio: 1. Ingeniería de materiales 2. Geociencia 3. Computación 4. Física 5. Biología")
    
    subject = input("Elige un número: ")
    
    if subject == "1":
        subject_words = words["materials science and engineering"]
    elif subject == "2":
        subject_words = words["geoscience"]
    elif subject == "3":
        subject_words = words["computer science"]
    elif subject == "4":
        subject_words = words["physics"]
    elif subject == "5":
        subject_words = words["biology"]
    else:
        print("Selección no válida.")
        return

    quiz_user(subject_words)

if __name__ == "__main__":
    main()
# Out:
# ¡Bienvenido a la aplicación para el aprendizaje de vocabulario de ciencia en español!
# Presiona 'enter' para empezar a aprender...
# Elige un tema de estudio: 1. Ingeniería de materiales 2. Geociencia 3. Computación 4. Física 5. Biología
# Elige un número:  1
# ¿Cuál es la traducción de 'insulator'?
# Tu respuesta:  insulador
# ¡Incorrecto! La respuesta correcta es 'aislante'.
#
# ¿Cuál es la traducción de 'structure'?
# Tu respuesta:  estructuro
# ¡Incorrecto! La respuesta correcta es 'estructura'.
#
# ¿Cuál es la traducción de 'composite'?
# Tu respuesta:
# ¡Incorrecto! La respuesta correcta es 'composite'.
#
# ¿Cuál es la traducción de 'microstructure'?
# Tu respuesta:
# ¡Incorrecto! La respuesta correcta es 'microestructura'.
#
# ¿Cuál es la traducción de 'tensile strength'?
# Tu respuesta:  exit()
# ¡Incorrecto! La respuesta correcta es 'resistencia a la tracción'.
#
# ¿Cuál es la traducción de 'conductivity'?
# Tu respuesta:  exit
# ...

# %%
print(words)
# Out:
# {'materials science and engineering': [('insulator', 'aislante'), ('structure', 'estructura'), ('composite', 'composite'), ('microstructure', 'microestructura'), ('tensile strength', 'resistencia a la tracción'), ('conductivity', 'conductividad'), ('polymer', 'polímero'), ('composition', 'composición'), ('molding', 'moldeo'), ('conductive material', 'material conductivo'), ('vibration', 'vibración'), ('fluctuation', 'fluctuación'), ('compression', 'compresión'), ('flexibility', 'flexibilidad'), ('alloy', 'aleación'), ('adhesion', 'adhesión'), ('precipitation', 'precipitación'), ('glass', 'vidrio'), ('load', 'carga'), ('welding', 'soldadura'), ('biodegradable material', 'material biodegradable'), ('materials', 'materiales'), ('plastic', 'plástico'), ('superalloy', 'superaleación'), ('temperature', 'temperatura'), ('optical property', 'propiedad óptica'), ('strength', 'resistencia'), ('thermal expansion', 'expansión térmica'), ('ductility', 'ductilidad'), ('surface', 'superficie'), ('n
# ...

# %%
import json
with open("dict.json", 'w') as file:
    json.dump(words, file, indent=4)

# %%
with open("dict.json", "r") as file:
    inwords = json.load(file)
print(inwords)
# Out:
# {'materials science and engineering': [['insulator', 'aislante'], ['structure', 'estructura'], ['composite', 'composite'], ['microstructure', 'microestructura'], ['tensile strength', 'resistencia a la tracción'], ['conductivity', 'conductividad'], ['polymer', 'polímero'], ['composition', 'composición'], ['molding', 'moldeo'], ['conductive material', 'material conductivo'], ['vibration', 'vibración'], ['fluctuation', 'fluctuación'], ['compression', 'compresión'], ['flexibility', 'flexibilidad'], ['alloy', 'aleación'], ['adhesion', 'adhesión'], ['precipitation', 'precipitación'], ['glass', 'vidrio'], ['load', 'carga'], ['welding', 'soldadura'], ['biodegradable material', 'material biodegradable'], ['materials', 'materiales'], ['plastic', 'plástico'], ['superalloy', 'superaleación'], ['temperature', 'temperatura'], ['optical property', 'propiedad óptica'], ['strength', 'resistencia'], ['thermal expansion', 'expansión térmica'], ['ductility', 'ductilidad'], ['surface', 'superficie'], ['n
# ...
